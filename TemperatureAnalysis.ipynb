# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul5569/FFXIVBenchmarkAnalysis/blob/main/TemperatureAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Upload or load file

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b7fd5fe9-799d-4931-936a-f574405f536d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7fd5fe9-799d-4931-936a-f574405f536d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#url = 'https://github.com/rahul5569/FFXIVBenchmarkAnalysis/blob/4dce662b0cd1beb8b92de4100d2fbbbf53c7284b/Temperature.CSV'
# df = pd.read_csv(url, on_bad_lines='skip')
# df

import io 

df = pd.read_csv(io.BytesIO(uploaded['Temperature3.CSV']),encoding="ISO-8859-1", on_bad_lines='skip')
df
# Out:
#            Date     Time            Virtual Memory Committed [MB]  \
# 0     6.10.2022  25:51.2                                     6953
# 1     6.10.2022  25:53.2                                     6936
# 2     6.10.2022  25:55.4                                     6926
# 3     6.10.2022  25:57.4                                     6929
# 4     6.10.2022  25:59.5                                     6920
# ...         ...      ...                                      ...
# 3540  6.10.2022  28:40.8                                     7406
# 3541  6.10.2022  28:42.9                                     7428
# 3542  6.10.2022  28:44.9                                     7427
# 3543       Date     Time            Virtual Memory Committed [MB]
# 3544        NaN      NaN  System: ASUS Zephyrus G GU502DU_GA502DU
#
#                 Virtual Memory Available [MB]  \
# 0                                       26646
# 1                                       26663
# ...

# %%
for col in df.columns:
  print(col)
# Out:
# Date
# Time
# Virtual Memory Committed [MB]
# Virtual Memory Available [MB]
# Virtual Memory Load [%]
# Physical Memory Used [MB]
# Physical Memory Available [MB]
# Physical Memory Load [%]
# Page File Usage [%]
# Core VIDs (avg) [V]
# Core 0 VID [V]
# Core 1 VID [V]
# Core 2 VID [V]
# Core 3 VID [V]
# Core Clocks (avg) [MHz]
# Core 0 Clock [MHz]
# Core 1 Clock [MHz]
# Core 2 Clock [MHz]
# Core 3 Clock (perf #1) [MHz]
# Bus Clock [MHz]
# Core Effective Clocks (avg) [MHz]
# Core 0 T0 Effective Clock [MHz]
# Core 0 T1 Effective Clock [MHz]
# Core 1 T0 Effective Clock [MHz]
# Core 1 T1 Effective Clock [MHz]
# Core 2 T0 Effective Clock [MHz]
# Core 2 T1 Effective Clock [MHz]
# Core 3 T0 Effective Clock [MHz]
# Core 3 T1 Effective Clock [MHz]
# Average Effective Clock [MHz]
# Core Usage (avg) [%]
# Core 0 T0 Usage [%]
# Core 0 T1 Usage [%]
# Core 1 T0 Usage [%]
# Core 1 T1 Usage [%]
# Core 2 T0 Usage [%]
# Core 2 T1 Usage [%]
# Core 3 T0 Usage [%]
# Core 3 T1 Usage [%]
# ...

# %%
sns.displot(
    data=df,
    x="Time", y= "GPU Temperature [Â°C].1")
